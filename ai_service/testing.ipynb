# %%
try:
    import sklearn, pandas, numpy, flask, fastapi
    print('All libraries present!')
except ImportError as e:
    print (f'Missing: {e}')
# Out:
# All libraries present!

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: scikit-learn==1.6.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.6.1)
# Requirement already satisfied: pandas==2.2.3 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: numpy==2.1.3 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: flask==3.1.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: sqlalchemy==2.0.39 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (2.0.39)
# Requirement already satisfied: psycopg2-binary==2.9.11 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (2.9.11)
# Requirement already satisfied: redis==7.2.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (7.2.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn==1.6.1->-r requirements.txt (line 1)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn==1.6.1->-r requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn==1.6.1->-r requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas==2.2.3->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask==3.1.0->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask==3.1.0->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask==3.1.0->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask==3.1.0->-r requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask==3.1.0->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\king agyepong\anaconda3\lib\site-packages (from sqlalchemy==2.0.39->-r requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from sqlalchemy==2.0.39->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: colorama in c:\users\king agyepong\anaconda3\lib\site-packages (from click>=8.1.3->flask==3.1.0->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask==3.1.0->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\king agyepong\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn, pandas, numpy, flask, fastapi, psycopg2, redis, sqlalchemy

packages = [sklearn, pandas, numpy, flask, psycopg2, redis, sqlalchemy]
names = ["scikit-learn", "pandas", "numpy", "flask", "psycopg2-binary", "redis", "sqlalchemy"]

for name, pkg in zip(names, packages):
    print(f"{name}=={pkg.__version__}")
# Out:
# scikit-learn==1.6.1
# pandas==2.2.3
# numpy==2.1.3
# flask==3.1.0
# psycopg2-binary==2.9.11 (dt dec pq3 ext lo64)
# redis==7.2.1
# sqlalchemy==2.0.39
# C:\Users\King Agyepong\AppData\Local\Temp\ipykernel_2156\9526133.py:7: DeprecationWarning: The '__version__' attribute is deprecated and will be removed in Flask 3.1. Use feature detection or 'importlib.metadata.version("flask")' instead.
#   print(f"{name}=={pkg.__version__}")

# %%
import pandas as pd
import glob

# Load CSVs from data folder
files = glob.glob('data/*.csv')
print(f'Found {len(files)} CSV files:')

for f in files:
    df = pd.read_csv(f, nrows=3)
    print(f'\n--- {f} ---')
    print('Columns:', df.columns.tolist())
    print(df.head(2))
# Out:
# Found 3 CSV files:
#
# --- data\Car_features_and_msrp.csv ---
# Columns: ['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 'Driven_Wheels', 'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style', 'highway MPG', 'city mpg', 'Popularity', 'MSRP']
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)        335
# 1  BMW    1 Series  2011  premium unleaded (required)        300
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                 6            MANUAL  rear wheel drive                2
# 1                 6            MANUAL  rear wheel drive                2
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
#
# --- data\Car_price_prediction.csv ---
# Columns: ['Unnamed: 0', 'name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner', 'seats', 'max_power (in bph)', 'Mileage Unit', 'Mileage', 'Engine (CC)']
#    Unnamed: 0     name  year  selling_price  km_driven    fuel seller_type  \
# 0           0   Maruti  2014         450000     145500  Diesel  Individual
# 1           2  Hyundai  2010         225000     127000  Diesel  Individual
#
#   transmission        owner  seats  max_power (in bph) Mileage Unit  Mileage  \
# 0       Manual  First Owner      5                74.0         kmpl     23.4
# 1       Manual  First Owner      5                90.0         kmpl     23.0
#
#    Engine (CC)
# 0         1248
# 1         1396
#
# --- data\OLX_cars_dataset00.csv ---
# Columns: ['Ad ID', 'Car Name', 'Make', 'Model', 'Year', "KM's driven", 'Price', 'Fuel', 'Registration city', 'Car documents', 'Assembly', 'Transmission', 'Condition', 'Seller Location', 'Description', 'Car Features', "Images URL's", 'Car Profile']
#         Ad ID                      Car Name    Make  Model  Year  KM's driven  \
# 0  1079071571  fresh import Passo 2021model  Toyota  Passo  2021        54000
# 1  1080125520                   Suzuki ravi  Suzuki   Ravi  2018        95000
#
#      Price    Fuel Registration city Car documents  Assembly Transmission  \
# 0  4190000  Petrol      Unregistered      Original  Imported    Automatic
# 1  1300000  Petrol           Karachi      Original     Local       Manual
#
#   Condition            Seller Location  \
# 0      Used  Airline Avenue, Islamabad
# 1      Used         Kahuta, Rawalpindi
#
#                                          Description  \
# 0  it's 2021 model fresh import, perfect engine s...
# 1                              Suzuki ravi 2018 col
#
#                                         Car Features  \
# 0  ABS, Air Bags, AM/FM Radio, CD Player, Cassett...
# 1                                        AM/FM Radio
#
#                                         Images URL's  \
# 0  ['https://images.olx.com.pk/thumbnails/4039460...
# 1  ['https://images.olx.com.pk/thumbnails/4102504...
#
#                                          Car Profile
# 0  https://www.olx.com.pk/item/fresh-import-passo...
# 1  https://www.olx.com.pk/item/suzuki-ravi-iid-10...

# %%
from csv_loader import load_Kaggle_vehicles

vehicles = load_Kaggle_vehicles()

print('Shape:', vehicles.shape)
print('Columns:', vehicles.columns.tolist())
print('Sample data:')
print(vehicles[['make', 'model', 'year', 'price', 'fuel_type', 'description']].head(10))

# Check for missing values
print('\nMissing values per column:')
print(vehicles.isnull().sum())
# Out:
# ✅ Loaded 18664 vehicles from 3 CSV file(s)
# Shape: (18664, 10)
# Columns: ['make', 'model', 'year', 'price', 'mileage', 'fuel_type', 'transmission', 'body_type', 'description', 'vehicle_id']
# Sample data:
#   make       model  year  price                    fuel_type description
# 0  Bmw  1 Series M  2011  46135  Premium Unleaded (Required)     Compact
# 1  Bmw    1 Series  2011  40650  Premium Unleaded (Required)     Compact
# 2  Bmw    1 Series  2011  36350  Premium Unleaded (Required)     Compact
# 3  Bmw    1 Series  2011  29450  Premium Unleaded (Required)     Compact
# 4  Bmw    1 Series  2011  34500  Premium Unleaded (Required)     Compact
# 5  Bmw    1 Series  2012  31200  Premium Unleaded (Required)     Compact
# 6  Bmw    1 Series  2012  44100  Premium Unleaded (Required)     Compact
# 7  Bmw    1 Series  2012  39300  Premium Unleaded (Required)     Compact
# 8  Bmw    1 Series  2012  36900  Premium Unleaded (Required)     Compact
# 9  Bmw    1 Series  2013  37200  Premium Unleaded (Required)     Compact
#
# Missing values per column:
# make               0
# model           1447
# year               0
# price              0
# mileage            0
# fuel_type          3
# transmission       0
# body_type       6671
# description        0
# vehicle_id         0
# dtype: int64

# %%
# Test CSV loader
vehicles = load_Kaggle_vehicles('data/')
print(f'Vehicles loaded: {len(vehicles)}')
print(vehicles[['make', 'model', 'year', 'price']].head(5))
# Out:
# ✅ Loaded 18664 vehicles from 3 CSV file(s)
# Vehicles loaded: 18664
#   make       model  year  price
# 0  Bmw  1 Series M  2011  46135
# 1  Bmw    1 Series  2011  40650
# 2  Bmw    1 Series  2011  36350
# 3  Bmw    1 Series  2011  29450
# 4  Bmw    1 Series  2011  34500

# %%
# Test Database connection
from database import fetch_vehicle_data, fetch_user_interactions

vehicles = fetch_vehicle_data()
interactions = fetch_user_interactions()

print(f'Vehicles loaded: {len(vehicles)}')
print(f'Interactions loaded: {len(interactions)}')
print(vehicles.head())
# Out:
# Vehicles loaded: 0
# Interactions loaded: 0
# Empty DataFrame
# Columns: [vehicle_id, make, model, year, price, fuel_type, transmission, body_type, mileage, color, description]
# Index: []

# %%
# Test the recommendation engine
from recommender import VehicleRecommendationEngine

engine = VehicleRecommendationEngine()
engine.train(fetch_user_interactions(), fetch_vehicle_data())

# Replace with real user ID from database
recs = engine.get_recommendations(user_id='user_123', n=5)
print('Recommendations:', recs)
# Out:
# Training recommendation model...
# ⚠️ No interaction data yet - skipping collaborativr filter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       2 from recommender import VehicleRecommendationEngine
#       4 engine = VehicleRecommendationEngine()
# ----> 5 engine.train(fetch_user_interactions(), fetch_vehicle_data())
#       7 # Replace with real user ID from database
#       8 recs = engine.get_recommendations(user_id='user_123', n=5)
#
# File ~\OneDrive\Documents\GitHub\AutoSphere_max\AutoSphere\ai_service\recommender.py:120, in VehicleRecommendationEngine.train(self, interactions_df, vehicle_df)
#     117     self.user_item_matrix = self.build_user_item_matrix(interactions_df)
#     118     self.train_collabrative_filter()
# --> 120 self.build_vehicle_features(vehicle_df)
#     121 print('✅ Model fully tained and ready!')
#
# File ~\OneDrive\Documents\GitHub\AutoSphere_max\AutoSphere\ai_service\recommender.py:74, in VehicleRecommendationEngine.build_vehicle_features(self, vehicle_df)
#      72 # Numeric features - normalize price and mileage
#      73 scaler = StandardScaler()
# ---> 74 features[['price_norm', 'mileage_norm', 'year_norm']] = scaler.fit_transform(
#      75     vehicle_df[['price', 'mileage', 'year']].fillna(0)
#      76 )
#      78 # Caterogical features - one-hot encode
#      79 fuel_dummies = pd.get_dummies(vehicle_df['fuel_type'], prefix='fuel')
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     903         warnings.warn(
#     904             (
#     905                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     913             UserWarning,
#     914         )
#     916 if y is None:
#     917     # fit method of arity 1 (unsupervised transformation)
# --> 918     return self.fit(X, **fit_params).transform(X)
#     919 else:
#     920     # fit method of arity 2 (supervised transformation)
#     921     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:894, in StandardScaler.fit(self, X, y, sample_weight)
#     892 # Reset internal state before fitting
#     893 self._reset()
# --> 894 return self.partial_fit(X, y, sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:930, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     898 """Online computation of mean and std on X for later scaling.
#     899
#     900 All of X is processed as a single batch. This is intended for cases
#    (...)
#     927     Fitted scaler.
#     928 """
#     929 first_call = not hasattr(self, "n_samples_seen_")
# --> 930 X = validate_data(
#     931     self,
#     932     X,
#     933     accept_sparse=("csr", "csc"),
#     934     dtype=FLOAT_DTYPES,
#     935     ensure_all_finite="allow-nan",
#     936     reset=first_call,
#     937 )
#     938 n_features = X.shape[1]
#     940 if sample_weight is not None:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1130, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128     n_samples = _num_samples(array)
#    1129     if n_samples < ensure_min_samples:
# -> 1130         raise ValueError(
#    1131             "Found array with %d sample(s) (shape=%s) while a"
#    1132             " minimum of %d is required%s."
#    1133             % (n_samples, array.shape, ensure_min_samples, context)
#    1134         )
#    1136 if ensure_min_features > 0 and array.ndim == 2:
#    1137     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required by StandardScaler.
