# %%
try:
    import sklearn, pandas, numpy, flask, fastapi
    print('All libraries present!')
except ImportError as e:
    print (f'Missing: {e}')
# Out:
# All libraries present!

# %%
pip install scikit-learn pandas numpy flask fastapi uvicorn psycopg2-binary redis
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\king agyepong\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: pandas in c:\users\king agyepong\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\king agyepong\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: flask in c:\users\king agyepong\anaconda3\lib\site-packages (3.1.0)
# Collecting fastapi
#   Downloading fastapi-0.134.0-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting redis
#   Downloading redis-7.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\king agyepong\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\king agyepong\anaconda3\lib\site-packages (from flask) (1.9.0)
# Collecting starlette>=0.46.0 (from fastapi)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from fastapi) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from fastapi) (4.12.2)
# Collecting typing-inspection>=0.4.2 (from fastapi)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\king agyepong\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\king agyepong\anaconda3\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\king agyepong\anaconda3\lib\site-packages (from pydantic>=2.7.0->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from pydantic>=2.7.0->fastapi) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\king agyepong\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\king agyepong\anaconda3\lib\site-packages (from starlette>=0.46.0->fastapi) (4.7.0)
# Requirement already satisfied: idna>=2.8 in c:\users\king agyepong\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\king agyepong\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (1.3.0)
# Downloading fastapi-0.134.0-py3-none-any.whl (110 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.7 MB 1.4 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.6 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.6 MB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 1.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 1.0 MB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 1.1 MB/s eta 0:00:00
# Downloading redis-7.2.1-py3-none-any.whl (396 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, redis, psycopg2-binary, annotated-doc, uvicorn, starlette, fastapi
#
#    ---------------------------------------- 0/7 [typing-inspection]
#    ---------------------------------------- 0/7 [typing-inspection]
#    ---------------------------------------- 0/7 [typing-inspection]
#    ---------------------------------------- 0/7 [typing-inspection]
#    ---------------------------------------- 0/7 [typing-inspection]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----- ---------------------------------- 1/7 [redis]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------- ---------------------------- 2/7 [psycopg2-binary]
#    ----------------- ---------------------- 3/7 [annotated-doc]
#    ----------------- ---------------------- 3/7 [annotated-doc]
#    ----------------- ---------------------- 3/7 [annotated-doc]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------- ----------------- 4/7 [uvicorn]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------- ----------- 5/7 [starlette]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------- ----- 6/7 [fastapi]
#    ---------------------------------------- 7/7 [fastapi]
#
# Successfully installed annotated-doc-0.0.4 fastapi-0.134.0 psycopg2-binary-2.9.11 redis-7.2.1 starlette-0.52.1 typing-inspection-0.4.2 uvicorn-0.41.0

# %%
import sklearn, pandas, numpy, flask, fastapi, psycopg2, redis

packages = [sklearn, pandas, numpy, flask, psycopg2, redis]
names = ["scikit-learn", "pandas", "numpy", "flask", "psycopg2-binary", "redis"]

for name, pkg in zip(names, packages):
    print(f"{name}=={pkg.__version__}")
# Out:
# scikit-learn==1.6.1
# pandas==2.2.3
# numpy==2.1.3
# C:\Users\King Agyepong\AppData\Local\Temp\ipykernel_10128\2884310428.py:7: DeprecationWarning: The '__version__' attribute is deprecated and will be removed in Flask 3.1. Use feature detection or 'importlib.metadata.version("flask")' instead.
#   print(f"{name}=={pkg.__version__}")
# flask==3.1.0
# psycopg2-binary==2.9.11 (dt dec pq3 ext lo64)
# redis==7.2.1

# %%
import pandas as pd
import glob

# Load CSVs from data folder
files = glob.glob('data/*.csv')
print(f'Found {len(files)} CSV files:')

for f in files:
    df = pd.read_csv(f, nrows=3)
    print(f'\n--- {f} ---')
    print('Columns:', df.columns.tolist())
    print(df.head(2))
# Out:
# Found 3 CSV files:
#
# --- data\Car_features_and_msrp.csv ---
# Columns: ['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 'Driven_Wheels', 'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style', 'highway MPG', 'city mpg', 'Popularity', 'MSRP']
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)        335
# 1  BMW    1 Series  2011  premium unleaded (required)        300
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                 6            MANUAL  rear wheel drive                2
# 1                 6            MANUAL  rear wheel drive                2
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
#
# --- data\Car_price_prediction.csv ---
# Columns: ['Unnamed: 0', 'name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type', 'transmission', 'owner', 'seats', 'max_power (in bph)', 'Mileage Unit', 'Mileage', 'Engine (CC)']
#    Unnamed: 0     name  year  selling_price  km_driven    fuel seller_type  \
# 0           0   Maruti  2014         450000     145500  Diesel  Individual
# 1           2  Hyundai  2010         225000     127000  Diesel  Individual
#
#   transmission        owner  seats  max_power (in bph) Mileage Unit  Mileage  \
# 0       Manual  First Owner      5                74.0         kmpl     23.4
# 1       Manual  First Owner      5                90.0         kmpl     23.0
#
#    Engine (CC)
# 0         1248
# 1         1396
#
# --- data\OLX_cars_dataset00.csv ---
# Columns: ['Ad ID', 'Car Name', 'Make', 'Model', 'Year', "KM's driven", 'Price', 'Fuel', 'Registration city', 'Car documents', 'Assembly', 'Transmission', 'Condition', 'Seller Location', 'Description', 'Car Features', "Images URL's", 'Car Profile']
#         Ad ID                      Car Name    Make  Model  Year  KM's driven  \
# 0  1079071571  fresh import Passo 2021model  Toyota  Passo  2021        54000
# 1  1080125520                   Suzuki ravi  Suzuki   Ravi  2018        95000
#
#      Price    Fuel Registration city Car documents  Assembly Transmission  \
# 0  4190000  Petrol      Unregistered      Original  Imported    Automatic
# 1  1300000  Petrol           Karachi      Original     Local       Manual
#
#   Condition            Seller Location  \
# 0      Used  Airline Avenue, Islamabad
# 1      Used         Kahuta, Rawalpindi
#
#                                          Description  \
# 0  it's 2021 model fresh import, perfect engine s...
# 1                              Suzuki ravi 2018 col
#
#                                         Car Features  \
# 0  ABS, Air Bags, AM/FM Radio, CD Player, Cassett...
# 1                                        AM/FM Radio
#
#                                         Images URL's  \
# 0  ['https://images.olx.com.pk/thumbnails/4039460...
# 1  ['https://images.olx.com.pk/thumbnails/4102504...
#
#                                          Car Profile
# 0  https://www.olx.com.pk/item/fresh-import-passo...
# 1  https://www.olx.com.pk/item/suzuki-ravi-iid-10...

# %%
from csv_loader import load_Kaggle_vehicles

vehicles = load_Kaggle_vehicles()

print('Shape:', vehicles.shape)
print('Columns:', vehicles.columns.tolist())
print('Sample data:')
print(vehicles[['make', 'model', 'year', 'price', 'fuel_type', 'description']].head(10))

# Check for missing values
print('\nMissing values per column:')
print(vehicles.isnull().sum())
# Out:
# ✅ Loaded 18664 vehicles from 3 CSV file(s)
# Shape: (18664, 10)
# Columns: ['make', 'model', 'year', 'price', 'mileage', 'fuel_type', 'transmission', 'body_type', 'description', 'vehicle_id']
# Sample data:
#   make       model  year  price                    fuel_type description
# 0  Bmw  1 Series M  2011  46135  Premium Unleaded (Required)     Compact
# 1  Bmw    1 Series  2011  40650  Premium Unleaded (Required)     Compact
# 2  Bmw    1 Series  2011  36350  Premium Unleaded (Required)     Compact
# 3  Bmw    1 Series  2011  29450  Premium Unleaded (Required)     Compact
# 4  Bmw    1 Series  2011  34500  Premium Unleaded (Required)     Compact
# 5  Bmw    1 Series  2012  31200  Premium Unleaded (Required)     Compact
# 6  Bmw    1 Series  2012  44100  Premium Unleaded (Required)     Compact
# 7  Bmw    1 Series  2012  39300  Premium Unleaded (Required)     Compact
# 8  Bmw    1 Series  2012  36900  Premium Unleaded (Required)     Compact
# 9  Bmw    1 Series  2013  37200  Premium Unleaded (Required)     Compact
#
# Missing values per column:
# make               0
# model           1447
# year               0
# price              0
# mileage            0
# fuel_type          3
# transmission       0
# body_type       6671
# description        0
# vehicle_id         0
# dtype: int64
